# %%
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API key for Google Gemini: ")
# Out:
# Enter API key for Google Gemini: ··········

# %%
from langchain.chat_models import init_chat_model

# %%
# ! pip install -U langchain-google-genai

# %%
model_gemini = init_chat_model("gemini-2.5-flash", model_provider="google_genai")

# %%
model_gemini.invoke("Hello, world!")
# Out:
# AIMessage(content='Hello there! Welcome! How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--c47dd99c-a43b-4eaa-8d47-6ec10f2bc810-0', usage_metadata={'input_tokens': 5, 'output_tokens': 46, 'total_tokens': 51, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 34}})

# %%
# ! pip install -U langchain-openai

# %%
if not os.environ.get("OPENAI_API_KEY"):
  os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter API key for OpenAI: ")

# %%
from langchain.chat_models import init_chat_model

model_openai = init_chat_model("gpt-4o-mini", model_provider="openai")

# %%
model_openai.invoke("Hello, world!")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 11, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CAAPv6J38pTitHFV1GtPfIHQhUpUS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--68da097b-ea99-4e56-9848-ef73dc54e6bf-0', usage_metadata={'input_tokens': 11, 'output_tokens': 9, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
